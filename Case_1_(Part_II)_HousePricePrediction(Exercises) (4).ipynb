# %% [markdown]
# # House price prediction for Denver Dataset
#
# In this case (Part II), there are two main tasks:
#
# - First, you will need to split the train data into train and validate data and tune the model hyperparameters to choose the best model. Submit the predicted prices for test data to Kaggle to compete for Prof. X's Prize!
#
# - Then you will examine the profit of the iBuyer business model based on the predicted price on the valid data.

# %% [markdown]
# You need to submit a report in pdf format containing the following material on canvas site:
#
# 1.   A plot of the training errors and validation errors over epochs for a base multilayer perceptron model with 2 hidden layers of sizes 256 and 128.
#
# 2.   A plot of the training errors and validation errors over epochs for a  multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64.
#
# 3.  A plot of the training errors and validation errors over epochs for a  multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64
# and norm regularization.
#
# 4. A plot of the training errors and validation errors over epochs for a  multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64
# and norm regularization and dropout layers.
#
# 5. A table listing all the model hyperparameters that you have tried with the corresponding validation errors that you found.
#
# 6. Your profit analysis of the the iBuyer business model based on the predicted price on the valid data and answers to the four questions therein.
#
#
# You also need to submit on canvas site:
#
# - The complete Juyputer notebook containing all your Pytorch code with explanations, along with a Markdown text explaining different parts if needed.
# -  A checkpoint.pth file containing all the necessary information to retrieve your best model and predictions.

# %% [markdown]
# ---
# ## Data Loading and Visualize Data

# %% [markdown]
# The train data and test data are available on Kaggle website.
# You can first download them, then upload them to the google colab, and then read the data using pandas.

# %%
import pandas as pd  # Importing pandas, which is a library for data manipulation and analysis
#TODO: Read the datasets
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
# Display the train dataframe
print(train_df.shape)
print(train_df.columns)
# Out:
# (11581, 17)
# Index(['ID', 'NBHD', 'PROP_CLASS', 'LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA',
#        'LAND_SQFT', 'GRD_AREA', 'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B',
#        'HLF_B', 'STORY', 'STYLE_CN', 'UNITS', 'SALE_PRICE'],
#       dtype='object')

# %%
# Display the test dataframe
print(test_df.shape)
print(test_df.columns)
# Out:
# (4964, 16)
# Index(['ID', 'NBHD', 'PROP_CLASS', 'LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA',
#        'LAND_SQFT', 'GRD_AREA', 'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B',
#        'HLF_B', 'STORY', 'STYLE_CN', 'UNITS'],
#       dtype='object')

# %% [markdown]
# As you can see, we have 11581 training samples and 4964 test samples, each with 16 features. The training samples contain the sale_prices, which are the labels. The test samples do not contain the sale_prices, which we will predict by building a MLP model.

# %% [markdown]
# ### Visualization of SALE PRICES
#
# Let's take a closer look at the sale prices in the train data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt  # Importing matplotlib's pyplot, it provides a MATLAB-like interface for making plots and charts

# Set the style
sns.set(style="whitegrid")

# Create a histogram
plt.figure(figsize=(10, 6))
sns.histplot(train_df['SALE_PRICE'], bins=50, color='blue')
plt.title('Histogram of Sale Prices (Train Data)')
plt.xlabel('Sale Price')
plt.ylabel('Number of Properties')
plt.show()

# %% [markdown]
# Check the minimum and maximum sale_price in train data.

# %%
print(train_df['SALE_PRICE'].min())
print(train_df['SALE_PRICE'].max())
print(train_df['SALE_PRICE'].median())
# Out:
# 51000
# 1995000
# 431000.0

# %% [markdown]
# We see that the sale_price has a wide range from 50K to 2 million, with the median price 431K.

# %% [markdown]
# ### Visualization of Correlation
#
# We can also compute and visualize the correlation matrix.

# %%
# Compute the correlation matrix:
correlation_matrix = train_df.corr()

# 1. Increase the figure size for clarity
plt.figure(figsize=(8, 8))

# 2. Use a heatmap with annotations, a color map, and specific formatting for the annotations
ax = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={'size': 8})

# 3. Rotate the x-axis labels for better visibility
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Rotate the y-axis labels
plt.setp(ax.get_yticklabels(), rotation=0)

# 4. Title and display
plt.title('Correlation Heatmap')
plt.tight_layout()  # This can help if any labels are still being cut off
plt.show()

# 5. Optionally save the figure with high resolution
# plt.savefig("heatmap.png", dpi=300)
# Out:
# <ipython-input-6-28da14c2e215>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = train_df.corr()

# %% [markdown]
# We can see that the Sale_Price has high correlation with Living_SQFT and number of Full Bathrooms.

# %% [markdown]
# ### Distribution of houses over different NBHD

# %%
# Compute the number of houses per neighborhood
House_by_NBHD = train_df['NBHD'].value_counts()
print(House_by_NBHD )
# Out:
# CENTRAL PARK                    1049
# GATEWAY / GREEN VALLEY RANCH     937
# UNION STATION                    369
# HAMPDEN                          346
# WINDSOR                          316
#                                 ...
# VALVERDE                          22
# GLOBEVILLE                        20
# SUN VALLEY                         8
# CORY - MERRILL                     4
# AURARIA                            1
# Name: NBHD, Length: 75, dtype: int64

# %%
# Filtering ZIP codes that appear more than once
filtered_House_by_NBHD = House_by_NBHD[House_by_NBHD > 200]
filtered_House_by_NBHD.plot(kind='bar', figsize=(10,6))
plt.title('Distribution of Houses by NBHD')
plt.ylabel('Number of Houses')
plt.xlabel('NBHD')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability, if necessary
plt.tight_layout()  # Ensure everything fits without overlapping
plt.show()

# %% [markdown]
# ---
# ## Data Preparation
#
# The first step when building a neural network model is getting your data into the proper form to feed into the network.
#
# - Train labels: We need to extract the sale prices from the train data as train labels. Since the house prices can take very large values, to make training fast it is helpful to define the train labels as the sale prices divided by a normalization factor.
#
# - **Handing non-numeric features**: Some of the house features are non-numeric. We will learn about how to process categorical data in the upcoming lectures. For now, you can  remove those non-numeric features and only train over the numeric features.
#
# - **Feature standardization**: When predicting house prices, you started from features that took a variety of ranges—some features had small floating-point values, and others had fairly large integer values. The model might be able to automatically adapt to such heterogeneous data, but it would definitely make learning more difficult. A widespread best practice for dealing with such data is to do feature-wise normalization: for each feature in the input data (a column in the input dataframe), we subtract the mean of the feature and divide by the standard deviation, so that the feature is centered around 0 and has
# a unit standard deviation. Note that here we combine the feature vectors in the train and test data. In this way, the train and test data go through the same normalization.
#
# - **Handling missing values**: There may exist some entries with missing values. After the feature standardization, we can impute the missing values with zeros.

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4964 entries, 0 to 4963
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           4964 non-null   int64
#  1   NBHD         4964 non-null   object
#  2   PROP_CLASS   4964 non-null   object
#  3   LIVING_SQFT  4964 non-null   int64
#  4   FBSMT_SQFT   4964 non-null   int64
#  5   BSMT_AREA    4964 non-null   int64
#  6   LAND_SQFT    4964 non-null   int64
#  7   GRD_AREA     4964 non-null   int64
#  8   BLDG_AGE     4964 non-null   int64
#  9   RM_AGE       2623 non-null   float64
#  10  BED_RMS      4964 non-null   float64
#  11  FULL_B       4964 non-null   float64
#  12  HLF_B        4964 non-null   int64
#  13  STORY        4964 non-null   float64
#  14  STYLE_CN     4964 non-null   object
#  15  UNITS        4964 non-null   float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 620.6+ KB

# %% [markdown]
# We see that the sale_price in train data has a wide range from 50K to 2 million, with the median price 431K. We can divide the sale_price by 100K, so the normalized sale_price is between 0.5 and 20 in training data. Remember, when we output the predicted price for the test data, we need to multiply back the normalization factor.

# %%
#TODO: define labels for train data
normalization_factor=100000
train_labels = train_df['SALE_PRICE']/normalization_factor
train_df.drop('SALE_PRICE', axis=1, inplace=True) # drop the sale_prices in features.

# %% [markdown]
# The inplace parameter, when set to True , allows you to drop the rows or columns without returning a new DataFrame. The issue arises when the drop function reorders the DataFrame, which can be problematic when the order of your data matters

# %% [markdown]
# Note that both the training samples and test samples contain an ID column, which is not informative for predicting the house price. Thus we will drop the ID column.

# %%
train_ID=train_df['ID']
test_ID=test_df['ID']
train_df.drop('ID', axis=1, inplace=True)
test_df.drop('ID', axis=1, inplace=True)

# %%
# Then we combine the feature vectors in the train data and test data
features=pd.concat(objs=[train_df,test_df],axis=0)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16545 entries, 0 to 4963
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NBHD         16545 non-null  object
#  1   PROP_CLASS   16545 non-null  object
#  2   LIVING_SQFT  16545 non-null  int64
#  3   FBSMT_SQFT   16545 non-null  int64
#  4   BSMT_AREA    16545 non-null  int64
#  5   LAND_SQFT    16545 non-null  int64
#  6   GRD_AREA     16545 non-null  int64
#  7   BLDG_AGE     16545 non-null  int64
#  8   RM_AGE       8705 non-null   float64
#  9   BED_RMS      16545 non-null  float64
#  10  FULL_B       16545 non-null  float64
#  11  HLF_B        16545 non-null  int64
#  12  STORY        16545 non-null  float64
#  13  STYLE_CN     16545 non-null  object
#  14  UNITS        16545 non-null  float64
# dtypes: float64(5), int64(7), object(3)
# memory usage: 2.0+ MB

# %% [markdown]
# We see that there are three non-numeric features, namely `NBHD`, `PROP_CLASS`, and `STYLE_CN`. We will apply one-hot encoding to those non-numeric features in our model; you could also simply drop these non-numeric features.

# %%
numeric_features = features.dtypes[features.dtypes != 'object'].index
non_numeric_features = features.dtypes[features.dtypes == 'object'].index
numeric_features, non_numeric_features
# Out:
# (Index(['LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA', 'LAND_SQFT', 'GRD_AREA',
#         'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B', 'HLF_B', 'STORY', 'UNITS'],
#        dtype='object'),
#  Index(['NBHD', 'PROP_CLASS', 'STYLE_CN'], dtype='object'))

# %%
# If you want to drop the non-numeric features, you just set drop_non_numeric_features= True.
drop_non_numeric_features= False

if drop_non_numeric_features:
    features= features.drop(non_numeric_features, axis=1)
else:
    # One-hot encode categorical features
    features = pd.get_dummies(features, columns=non_numeric_features, dummy_na=True)

# Check for non-numeric columns
non_numeric_cols = features.select_dtypes(include=['object']).columns
if not non_numeric_cols.empty:
    raise ValueError(f"DataFrame contains non-numeric columns: {non_numeric_cols.tolist()}")

# %%
# Standardize numeric features
features[numeric_features] = features[numeric_features].apply(lambda x: (x - x.mean()) / (x.std()))

# %%
# recheck the mean and std after standardization
features[numeric_features].mean(), features[numeric_features].std()
# Out:
# (LIVING_SQFT   -6.919686e-17
#  FBSMT_SQFT    -7.907445e-17
#  BSMT_AREA      5.829929e-17
#  LAND_SQFT      1.792998e-17
#  GRD_AREA      -1.975519e-17
#  BLDG_AGE      -1.385011e-17
#  RM_AGE         2.795645e-17
#  BED_RMS        2.122341e-16
#  FULL_B         1.469829e-16
#  HLF_B         -5.658145e-17
#  STORY         -4.563020e-18
#  UNITS          5.017175e-16
#  dtype: float64,
#  LIVING_SQFT    1.0
#  FBSMT_SQFT     1.0
#  BSMT_AREA      1.0
#  LAND_SQFT      1.0
#  GRD_AREA       1.0
#  BLDG_AGE       1.0
#  RM_AGE         1.0
#  BED_RMS        1.0
#  FULL_B         1.0
#  HLF_B          1.0
#  STORY          1.0
#  UNITS          1.0
#  dtype: float64)

# %% [markdown]
# We see that after standardization, the features for the train data have mean 0 and standard deviation 1.

# %%
# After the feature standardization, we can impute the missing values with zeros.
features[numeric_features] = features[numeric_features].fillna(0)

# %% [markdown]
# Double check the features after data processing.

# %%
features.info()
print(features.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16545 entries, 0 to 4963
# Columns: 105 entries, LIVING_SQFT to STYLE_CN_nan
# dtypes: float64(12), uint8(93)
# memory usage: 3.1 MB
# Index(['LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA', 'LAND_SQFT', 'GRD_AREA',
#        'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B', 'HLF_B',
#        ...
#        'STYLE_CN_3 STORY', 'STYLE_CN_BI-LEVEL', 'STYLE_CN_CONVERSION',
#        'STYLE_CN_END UNIT', 'STYLE_CN_MIDDLE UNIT', 'STYLE_CN_RANCH',
#        'STYLE_CN_SPLIT LEVEL', 'STYLE_CN_TRI-LEVEL', 'STYLE_CN_TRI-LEVEL W/B',
#        'STYLE_CN_nan'],
#       dtype='object', length=105)

# %% [markdown]
# Note that after the one-hot encoding of the non-numeric features, now we have 105-dimensional feature.

# %%
# check whether there is any missing entry
print(features.isnull().sum())
# Out:
# LIVING_SQFT               0
# FBSMT_SQFT                0
# BSMT_AREA                 0
# LAND_SQFT                 0
# GRD_AREA                  0
#                          ..
# STYLE_CN_RANCH            0
# STYLE_CN_SPLIT LEVEL      0
# STYLE_CN_TRI-LEVEL        0
# STYLE_CN_TRI-LEVEL W/B    0
# STYLE_CN_nan              0
# Length: 105, dtype: int64

# %%
# we extract out the train and test features
train_features = features.iloc[:len(train_labels)]
test_features = features.iloc[len(train_labels):]
train_features.shape, test_features.shape
# Out:
# ((11581, 105), (4964, 105))

# %%
import torch
import numpy as np

# Convert training features and labels to PyTorch tensors
train_features = torch.tensor(train_features.values.astype(np.float32), dtype=torch.float32)
test_features = torch.tensor(test_features.values.astype(np.float32), dtype=torch.float32)
train_labels = torch.tensor(train_labels.values.reshape(-1, 1).astype(np.float32), dtype=torch.float32)

# %%
train_labels
# Out:
# tensor([[ 2.8500],
#         [12.3000],
#         [ 4.2000],
#         ...,
#         [ 6.0200],
#         [ 3.8370],
#         [ 5.5000]])

# %%
train_labels.shape
# Out:
# torch.Size([11581, 1])

# %% [markdown]
# ---
# ## Training and Validation
#
# To prevent overfitting, we'll split it our training data into training and validation. We will use validation set to select the appropriate model.
# One way is to use the [`train_test_split` function](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html). You're more than welcome to use your own way.

# %%
#TODO: filling in the missing code to split train data into train and validation
from sklearn.model_selection import train_test_split  # Importing train_test_split function from sklearn for splitting data into training set and validation set
# Splitting the training data: 20% is validation data
train_indices, valid_indices = train_test_split(
    np.arange(len(features)), test_size=0.2, random_state=42)

train_features, valid_features, train_labels, valid_labels = train_test_split(
    train_features, train_labels, test_size=0.2, random_state=42)

# %%
print(train_features.shape)
print(valid_features.shape)
# Out:
# torch.Size([9264, 105])
# torch.Size([2317, 105])

# %% [markdown]
# ---
# ## DataLoaders and Batching
#
# After creating training, test, and validation data, we can create DataLoaders for this data by following two steps:
# 1. Create a known format for accessing our data, using [TensorDataset](https://pytorch.org/docs/stable/data.html#torch.utils.data.TensorDataset) which takes in an input set of data and a target set of data with the same first dimension, and creates a dataset.
# 2. Create DataLoaders and batch our training, validation, and test Tensor datasets. Note that we will shuffle the train data, so the model will not learn a particular order. For valid and test data, we do not shuffle.

# %%
from torch.utils.data import TensorDataset, DataLoader
train_data = TensorDataset(train_features, train_labels)
train_loader = DataLoader(train_data, batch_size=128, shuffle=True)
#TODO: create dataloader for validation data
valid_loader =DataLoader(TensorDataset(valid_features, valid_labels),batch_size=128)

# %%
test_data = TensorDataset(test_features)
test_loader = DataLoader(test_data, batch_size=128, shuffle=False)

# %% [markdown]
# Let's take a batch to have a sanity check

# %%
# obtain one batch of training data
dataiter = iter(train_loader)
features, labels = next(dataiter)

print('Sample input size: ', features.size()) # batch_size, seq_length
print('Sample input: \n', features)
print()
print('Sample label size: ', labels.size()) # batch_size
print('Sample label: \n', labels)
# Out:
# Sample input size:  torch.Size([128, 105])
# Sample input:
#  tensor([[-0.9552, -0.6920, -0.8231,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.2974,  0.8265,  0.5933,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.2116,  0.6458,  0.4813,  ...,  0.0000,  0.0000,  0.0000],
#         ...,
#         [-1.1478, -0.6920,  0.3295,  ...,  0.0000,  0.0000,  0.0000],
#         [ 1.1395, -0.6920, -0.8231,  ...,  0.0000,  0.0000,  0.0000],
#         [-0.7977, -0.6920, -0.8231,  ...,  0.0000,  0.0000,  0.0000]])
#
# Sample label size:  torch.Size([128, 1])
# Sample label:
#  tensor([[ 1.6200],
#         [ 4.9300],
#         [ 7.3750],
#         [ 6.7500],
#         [ 3.7000],
#         [ 5.3500],
#         [ 4.2000],
#         [ 3.5840],
#         [ 3.4500],
#         [ 4.0250],
#         [ 5.6200],
#         [ 4.6300],
#         [ 5.0645],
#         [ 3.6740],
#         [15.5000],
#         [ 2.0000],
#         [12.7539],
#         [ 6.2500],
#         [14.4000],
#         [ 1.1667],
#         [ 1.3500],
#         [ 5.3500],
#         [ 3.2000],
#         [ 7.1488],
#         [ 4.0700],
#         [ 2.3150],
#         [ 5.8000],
#         [ 4.7500],
#         [ 1.1500],
#         [ 6.8000],
#         [ 4.4250],
#         [10.0000],
#         [ 5.5000],
#         [ 5.8100],
#         [ 1.6790],
#         [ 1.7500],
#         [ 3.2200],
#         [ 3.8900],
#         [ 7.8600],
#         [ 9.2500],
#         [ 2.1500],
#         [ 4.2500],
#         [ 4.2000],
#         [ 6.4500],
#         [ 4.1990],
#         [ 6.2554],
#         [ 3.5043],
#         [10.7000],
#         [ 2.7500],
#         [ 8.0000],
#         [ 4.0900],
#         [ 3.9500],
#         [ 6.5100],
#         [ 3.4000],
#         [ 5.5000],
#         [ 2.4750],
#         [ 3.1500],
#         [ 3.2000],
#         [ 1.6000],
#         [ 3.1970],
#         [ 3.8300],
#         [ 4.0675],
#         [ 4.9000],
#         [ 8.6900],
#         [ 5.0000],
#         [ 3.9500],
#         [ 4.9900],
#         [ 4.7500],
#         [ 3.3680],
#         [ 3.5950],
#         [ 5.6862],
#         [ 3.1700],
#         [ 6.4000],
#         [ 3.9500],
#         [ 3.1500],
#         [ 2.6900],
#         [ 6.0100],
#         [11.2730],
#         [ 9.3800],
#         [ 4.4400],
#         [ 3.9300],
#         [14.5000],
#         [ 6.4000],
#         [ 3.9300],
#         [ 4.2500],
#         [ 3.9500],
#         [ 3.0000],
#         [ 7.4500],
#         [ 3.4500],
#         [ 3.0300],
#         [ 3.2500],
#         [17.6750],
#         [ 2.2438],
#         [ 4.4000],
#         [ 6.1000],
#         [ 3.4500],
#         [ 2.6600],
#         [ 4.3000],
#         [ 1.9200],
#         [ 6.9500],
#         [ 5.4000],
#         [ 3.2640],
#         [ 3.7000],
#         [ 8.3287],
#         [ 1.7000],
#         [15.0000],
#         [ 3.9500],
#         [ 2.4300],
#         [ 3.1500],
#         [ 3.1500],
#         [ 1.6750],
#         [12.6500],
#         [ 8.5400],
#         [ 4.7017],
#         [ 5.7000],
#         [ 2.4700],
#         [ 5.0000],
#         [15.7000],
#         [ 2.1250],
#         [ 6.2500],
#         [ 3.4990],
#         [ 3.2700],
#         [ 4.4496],
#         [ 5.6000],
#         [ 2.9000],
#         [ 3.2500],
#         [ 7.5400],
#         [ 6.8000]])

# %% [markdown]
# ---
# ## Linear Regression as Benchmark
#
# Let us build a linear regression model as a benchmark. Note that the linear regression model can be viewed as a special instance of multi-layer perception with no hidden layer and a single output neuron.

# %%
# Build a linear regression model network
import torch.nn as nn
lin_net = nn.Linear(train_features.shape[1], 1)

# %% [markdown]
# Let's print out the model achitecture.

# %%
lin_net
# Out:
# Linear(in_features=105, out_features=1, bias=True)

# %% [markdown]
# Let's take a batch and see the output

# %%
features, labels = next(dataiter)
output=lin_net(features)
output.shape,labels.shape
# Out:
# (torch.Size([128, 1]), torch.Size([128, 1]))

# %% [markdown]
# ---
# ## Train the model

# %% [markdown]
# First, we will use GPU training if it is availabe.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
lin_net = lin_net.to(device)

# %% [markdown]
# Second, let us specify the loss function.

# %%
#Since both the output and the label are real valued, we will use the standard mean-squared loss.
import torch
import torch.nn as nn

class MedianErrorRateLoss(nn.Module):
    def __init__(self):
        super(MedianErrorRateLoss, self).__init__()

    def forward(self, predicted, actual):
        # Calculate the absolute error for each prediction
        absolute_error = torch.abs((predicted - actual)/actual)

        return absolute_error

# Example usage:
criterion = MedianErrorRateLoss()

# %% [markdown]
# Third, while we are using the mean-squared loss for training loss, we will use
# a different metric to measure the predictive performance.
#
# Note that with house prices, as with stock prices, we care about relative quantities more than absolute quantities. Thus we tend to care more about the relative error than about the absolute error. For instance, if our prediction is off by \\$100,000 when estimating the sale price of a house which is \\$125,000, then we are probably doing a horrible job. On the other hand, if we err by this amount for a house with sale price \\$2 million, this might represent a pretty  accurate prediction.
#
# To address this issue, we will use the median error rate (MER) used by [Zestimate](https://www.zillow.com/z/zestimate/) to measure the predictive performance. The error rate is defined as
# $$
# \text{Error Rate} = \left| \frac{\text{Predicted Price}-\text{Actual Price}}{\text{Actual Price}} \right|
# $$
# The median error rate is defined as the median of error rates for all properties.

# %% [markdown]
# We are now ready to train the network. Let’s try training the model a bit longer: 200 epochs. To keep a record of how well the model does at each epoch, we will save the per-epoch training error and validation error in the training loop.

# %%
#TODO: Write code to train the network and save training and validation error.
def train(model, train_loader, valid_loader,num_epochs,learning_rate=0.001):
    train_losses = []                                       # To store training losses
    train_errors = []
    valid_losses=[]
    valid_errors=[]
    # To store training error rates
    # Initialize the optimizer, we use Adam here
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    for epoch in range(num_epochs):
        tot_valid_loss = 0.0
        tot_train_loss = 0.0                            # Store the total training MSE loss for this epoch
        train_error_rates =torch.tensor([]).to(device)  # Store the training error rates for this epoch
        valid_error_rates=torch.tensor([]).to(device)
        for features, labels in train_loader:           # For each batch in DataLoader
            # Move data to device (GPU or CPU)
            features = features.to(device)
            labels = labels.to(device)

            output = model(features)  # Compute the output
            loss = criterion(output, labels)  # Compute loss
            optimizer.zero_grad()  # Clear the gradients from previous iteration
            loss = loss.mean()
            loss.backward()  # Backpropagate the error
            optimizer.step()  # Update the weights

            tot_train_loss += loss.item()

            # Compute and store error rate for training data
            train_error_rate = torch.absolute(output/labels-1)
            train_error_rates= torch.cat((train_error_rates,train_error_rate),dim=0)


        train_loss = tot_train_loss /len(train_loader)
        train_error = torch.median(train_error_rates).item()
        train_losses.append(train_loss)
        train_errors.append(train_error)


        for valid_features, valid_labels in valid_loader:

            valid_features = valid_features.to(device)
            valid_labels = valid_labels.to(device)

            output = lin_net(valid_features)
            loss = criterion(output, valid_labels)
            optimizer.zero_grad()
            loss = loss.mean()
            loss.backward()
            optimizer.step()

            tot_valid_loss += loss.item()

            valid_error_rate = torch.absolute(output/valid_labels-1)
            valid_error_rates= torch.cat((valid_error_rates,valid_error_rate),dim=0)

        valid_loss = tot_valid_loss /len(valid_loader)
        valid_error = torch.median(valid_error_rates).item()
        valid_losses.append(valid_loss)
        valid_errors.append(valid_error)

        print("Epoch: {}/{}.. ".format(epoch+1, num_epochs),
          "Train Loss: {:.3f}.. ".format(train_loss),
          "Train Median Error Rate: {:.3f}.. ".format(train_error),
          "Validation Loss: {:.3f}.. ".format(valid_loss),
          "Validation Median Error Rate: {:.3f}.. ".format(valid_error))


        # Print the training loss and validation loss every 10 epochs
        if epoch % 10 == 0:
            print("Epoch: {}/{}.. ".format(epoch+1, num_epochs),
              "Train Loss: {:.3f}.. ".format(train_loss),
              "Train Median Error Rate: {:.3f}.. ".format(train_error),
              )


    return  train_losses,train_errors,valid_losses,valid_errors

# %%
train_losses,train_errors,valid_losses,valid_errors = train(lin_net, train_loader,valid_loader, num_epochs=200,learning_rate=0.001)
# Out:
# Epoch: 1/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 1/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..
# Epoch: 2/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 3/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 4/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 5/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 6/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 7/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 8/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 9/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 10/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 11/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 11/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..
# Epoch: 12/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 13/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 14/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 15/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 16/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 17/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 18/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 19/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 20/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 21/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 21/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..
# Epoch: 22/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 23/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 24/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 25/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 26/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 27/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 28/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 29/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 30/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 31/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 31/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..
# Epoch: 32/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 33/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 34/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 35/200..  Train Loss: 0.194..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 36/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 37/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 38/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 39/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 40/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 41/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 41/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..
# Epoch: 42/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 43/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 44/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 45/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 46/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 47/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 48/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 49/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 50/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 51/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 51/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..
# Epoch: 52/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 53/200..  Train Loss: 0.191..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 54/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 55/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 56/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 57/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 58/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 59/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 60/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 61/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 61/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..
# Epoch: 62/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 63/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 64/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 65/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 66/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 67/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 68/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 69/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 70/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 71/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 71/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..
# Epoch: 72/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 73/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 74/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 75/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 76/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 77/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 78/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 79/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 80/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 81/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 81/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..
# Epoch: 82/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 83/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 84/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 85/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 86/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 87/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 88/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 89/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 90/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 91/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 91/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..
# Epoch: 92/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 93/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 94/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 95/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 96/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 97/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 98/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 99/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 100/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 101/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 101/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..
# Epoch: 102/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 103/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 104/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 105/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 106/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 107/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 108/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 109/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 110/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 111/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 111/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..
# Epoch: 112/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 113/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 114/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 115/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 116/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 117/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 118/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 119/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 120/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 121/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 121/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..
# Epoch: 122/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 123/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 124/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 125/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 126/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 127/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 128/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 129/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 130/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 131/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 131/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..
# Epoch: 132/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 133/200..  Train Loss: 0.191..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 134/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 135/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 136/200..  Train Loss: 0.191..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 137/200..  Train Loss: 0.191..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 138/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 139/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 140/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 141/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 141/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..
# Epoch: 142/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 143/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 144/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 145/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 146/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 147/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 148/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 149/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 150/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 151/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 151/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..
# Epoch: 152/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 153/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 154/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 155/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 156/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 157/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 158/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 159/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 160/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 161/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 161/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..
# Epoch: 162/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 163/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 164/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 165/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 166/200..  Train Loss: 0.193..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 167/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 168/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 169/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 170/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 171/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 171/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..
# Epoch: 172/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 173/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 174/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 175/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 176/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 177/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 178/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 179/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.127..
# Epoch: 180/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 181/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.128..
# Epoch: 181/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..
# Epoch: 182/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 183/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 184/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.180..  Validation Median Error Rate: 0.125..
# Epoch: 185/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 186/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.180..  Validation Median Error Rate: 0.126..
# Epoch: 187/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 188/200..  Train Loss: 0.194..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 189/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 190/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 191/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 191/200..  Train Loss: 0.193..  Train Median Error Rate: 0.123..
# Epoch: 192/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 193/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 194/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 195/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 196/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 197/200..  Train Loss: 0.192..  Train Median Error Rate: 0.122..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 198/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..
# Epoch: 199/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.125..
# Epoch: 200/200..  Train Loss: 0.192..  Train Median Error Rate: 0.123..  Validation Loss: 0.181..  Validation Median Error Rate: 0.126..

# %% [markdown]
# Define a function to plot errors.

# %%
#TODO: Write code to plot the training and vadliation errors (MER) over epochs
import matplotlib.pyplot as plt

def plot_errors(errors1, errors2, num_epochs, label1, label2, title):
    plt.figure(figsize=(10, 7))
    plt.plot(range(1, num_epochs + 1), errors1, label=label1)
    plt.plot(range(1, num_epochs + 1), errors2, label=label2)
    plt.xlabel('Epoch')
    plt.ylabel('Median Error Rate (MER)')
    plt.title(title)
    plt.legend()
    plt.show()
plot_errors(train_errors, valid_errors, num_epochs=200, label1='Training Error', label2='Validation Error', title='Linear Regression: Training & Validation Errors (MER) Over Epochs')

# %% [markdown]
# ---
# ## Build the Multi-layer Perceptron Base Model

# %% [markdown]
# In the following, we build a multi-layer perception model with 2 hidden layers of sizes 256 and 128, respectively and ReLu activations.

# %%
# Build a feed-forward network
import torch.nn as nn
model1 = nn.Sequential(nn.Linear(train_features.shape[1], 256),
                      nn.ReLU(),
                      nn.Linear(256, 128),
                      nn.ReLU(),
                      nn.Linear(128,1))

# %% [markdown]
# Let's print out the model achitecture.

# %%
model1
# Out:
# Sequential(
#   (0): Linear(in_features=105, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=128, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
model1 = model1.to(device)

# %%
#TODO: write code to train the MLP network and save training and validation error.
def train(model, train_loader, valid_loader,num_epochs,learning_rate):
    train_losses = []                                       # To store training losses
    train_errors = []
    valid_losses=[]
    valid_errors=[]
    # To store training error rates
    # Initialize the optimizer, we use Adam here
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    for epoch in range(num_epochs):
        tot_valid_loss = 0.0
        tot_train_loss = 0.0                            # Store the total training MSE loss for this epoch
        train_error_rates =torch.tensor([]).to(device)  # Store the training error rates for this epoch
        valid_error_rates=torch.tensor([]).to(device)
        for features, labels in train_loader:           # For each batch in DataLoader
            # Move data to device (GPU or CPU)
            features = features.to(device)
            labels = labels.to(device)

            output = model(features)  # Compute the output
            loss = criterion(output, labels)  # Compute loss
            optimizer.zero_grad()  # Clear the gradients from previous iteration
            loss = loss.mean()
            loss.backward()  # Backpropagate the error

            optimizer.step()  # Update the weights

            tot_train_loss += loss.item()

            # Compute and store error rate for training data
            train_error_rate = torch.absolute(output/labels-1)
            train_error_rates= torch.cat((train_error_rates,train_error_rate),dim=0)


        train_loss = tot_train_loss /len(train_loader)
        train_error = torch.median(train_error_rates).item()
        train_losses.append(train_loss)
        train_errors.append(train_error)


        for valid_features, valid_labels in valid_loader:

            valid_features = valid_features.to(device)
            valid_labels = valid_labels.to(device)

            output = model(valid_features)
            loss = criterion(output, valid_labels)
            optimizer.zero_grad()
            loss = loss.mean()
            loss.backward()
            optimizer.step()

            tot_valid_loss += loss.item()

            valid_error_rate = torch.absolute(output/valid_labels-1)
            valid_error_rates= torch.cat((valid_error_rates,valid_error_rate),dim=0)

        valid_loss = tot_valid_loss /len(valid_loader)
        valid_error = torch.median(valid_error_rates).item()
        valid_losses.append(valid_loss)
        valid_errors.append(valid_error)

        print("Epoch: {}/{}.. ".format(epoch+1, num_epochs),
          "Train Loss: {:.3f}.. ".format(train_loss),
          "Train Median Error Rate: {:.3f}.. ".format(train_error),
          "Validation Loss: {:.3f}.. ".format(valid_loss),
          "Validation Median Error Rate: {:.3f}.. ".format(valid_error))


        # Print the training loss and validation loss every 10 epochs
        if epoch % 10 == 0:
            print("Epoch: {}/{}.. ".format(epoch+1, num_epochs),
              "Train Loss: {:.3f}.. ".format(train_loss),
              "Train Median Error Rate: {:.3f}.. ".format(train_error),
              )


    return  train_losses,train_errors,valid_losses,valid_errors

# %%
train_losses,train_errors,valid_losses,valid_errors = train(model1, train_loader,valid_loader, num_epochs=100,learning_rate=0.001)
# Out:
# Epoch: 1/100..  Train Loss: 0.415..  Train Median Error Rate: 0.320..  Validation Loss: 0.213..  Validation Median Error Rate: 0.154..
# Epoch: 1/100..  Train Loss: 0.415..  Train Median Error Rate: 0.320..
# Epoch: 2/100..  Train Loss: 0.199..  Train Median Error Rate: 0.127..  Validation Loss: 0.177..  Validation Median Error Rate: 0.117..
# Epoch: 3/100..  Train Loss: 0.183..  Train Median Error Rate: 0.113..  Validation Loss: 0.166..  Validation Median Error Rate: 0.109..
# Epoch: 4/100..  Train Loss: 0.175..  Train Median Error Rate: 0.106..  Validation Loss: 0.162..  Validation Median Error Rate: 0.109..
# Epoch: 5/100..  Train Loss: 0.171..  Train Median Error Rate: 0.104..  Validation Loss: 0.157..  Validation Median Error Rate: 0.105..
# Epoch: 89/100..  Train Loss: 0.107..  Train Median Error Rate: 0.056..  Validation Loss: 0.102..  Validation Median Error Rate: 0.056..
# Epoch: 90/100..  Train Loss: 0.107..  Train Median Error Rate: 0.057..  Validation Loss: 0.104..  Validation Median Error Rate: 0.058..
# Epoch: 91/100..  Train Loss: 0.108..  Train Median Error Rate: 0.056..  Validation Loss: 0.105..  Validation Median Error Rate: 0.060..
# Epoch: 91/100..  Train Loss: 0.108..  Train Median Error Rate: 0.056..
# Epoch: 92/100..  Train Loss: 0.109..  Train Median Error Rate: 0.060..  Validation Loss: 0.101..  Validation Median Error Rate: 0.056..
# Epoch: 93/100..  Train Loss: 0.108..  Train Median Error Rate: 0.058..  Validation Loss: 0.100..  Validation Median Error Rate: 0.055..
# Epoch: 94/100..  Train Loss: 0.107..  Train Median Error Rate: 0.057..  Validation Loss: 0.100..  Validation Median Error Rate: 0.055..
# Epoch: 95/100..  Train Loss: 0.106..  Train Median Error Rate: 0.056..  Validation Loss: 0.099..  Validation Median Error Rate: 0.054..
# Epoch: 96/100..  Train Loss: 0.106..  Train Median Error Rate: 0.056..  Validation Loss: 0.101..  Validation Median Error Rate: 0.057..
# Epoch: 97/100..  Train Loss: 0.105..  Train Median Error Rate: 0.055..  Validation Loss: 0.100..  Validation Median Error Rate: 0.054..
# Epoch: 98/100..  Train Loss: 0.106..  Train Median Error Rate: 0.057..  Validation Loss: 0.098..  Validation Median Error Rate: 0.054..
# Epoch: 99/100..  Train Loss: 0.105..  Train Median Error Rate: 0.056..  Validation Loss: 0.098..  Validation Median Error Rate: 0.052..
# Epoch: 100/100..  Train Loss: 0.104..  Train Median Error Rate: 0.055..  Validation Loss: 0.099..  Validation Median Error Rate: 0.054..

# %% [markdown]
# ## 1. A plot of the training errors and validation errors over epochs for a base multilayer perceptron model with 2 hidden layers of sizes 256 and 128.

# %%
#TODO: Write code to plot the training and validation error (MER) over epochs
plot_errors(train_errors, valid_errors, num_epochs=100, label1='Training Error', label2='Validation Error', title='Linear Regression: Training & Validation Errors (MER) Over Epochs')

# %% [markdown]
# ---
# ## Change network architecture

# %% [markdown]
# In the following, build a MLP with 4 hidden layer of sizes 512, 256, 128, 64, respectively.

# %%
#TODO: building a MLP with 4 hidden layer of sizes 512, 256, 128, 64,
model2 = nn.Sequential(nn.Linear(train_features.shape[1], 512),
                      nn.ReLU(),
                      nn.Linear(512, 256),
                      nn.ReLU(),
                      nn.Linear(256,128),
                      nn.ReLU(),
                      nn.Linear(128,64),
                      nn.ReLU(),
                      nn.Linear(64,1))
model2 = model2.to(device)

# %%
rain_losses,train_errors,valid_losses,valid_errors = train(model2, train_loader,valid_loader, num_epochs=100,learning_rate=0.001)
# Out:
# Epoch: 1/100..  Train Loss: 0.373..  Train Median Error Rate: 0.253..  Validation Loss: 0.203..  Validation Median Error Rate: 0.139..
# Epoch: 1/100..  Train Loss: 0.373..  Train Median Error Rate: 0.253..
# Epoch: 2/100..  Train Loss: 0.195..  Train Median Error Rate: 0.126..  Validation Loss: 0.173..  Validation Median Error Rate: 0.118..
# Epoch: 3/100..  Train Loss: 0.178..  Train Median Error Rate: 0.112..  Validation Loss: 0.163..  Validation Median Error Rate: 0.113..
  Validation Loss: 0.082..  Validation Median Error Rate: 0.044..
# Epoch: 89/100..  Train Loss: 0.090..  Train Median Error Rate: 0.049..  Validation Loss: 0.086..  Validation Median Error Rate: 0.047..
# Epoch: 90/100..  Train Loss: 0.088..  Train Median Error Rate: 0.048..  Validation Loss: 0.086..  Validation Median Error Rate: 0.050..
# Epoch: 91/100..  Train Loss: 0.089..  Train Median Error Rate: 0.049..  Validation Loss: 0.084..  Validation Median Error Rate: 0.047..
# Epoch: 91/100..  Train Loss: 0.089..  Train Median Error Rate: 0.049..
# Epoch: 92/100..  Train Loss: 0.090..  Train Median Error Rate: 0.050..  Validation Loss: 0.082..  Validation Median Error Rate: 0.043..
# Epoch: 93/100..  Train Loss: 0.089..  Train Median Error Rate: 0.050..  Validation Loss: 0.084..  Validation Median Error Rate: 0.047..
# Epoch: 94/100..  Train Loss: 0.088..  Train Median Error Rate: 0.049..  Validation Loss: 0.085..  Validation Median Error Rate: 0.045..
# Epoch: 95/100..  Train Loss: 0.089..  Train Median Error Rate: 0.050..  Validation Loss: 0.084..  Validation Median Error Rate: 0.046..
# Epoch: 96/100..  Train Loss: 0.094..  Train Median Error Rate: 0.055..  Validation Loss: 0.082..  Validation Median Error Rate: 0.045..
# Epoch: 97/100..  Train Loss: 0.088..  Train Median Error Rate: 0.048..  Validation Loss: 0.082..  Validation Median Error Rate: 0.044..
# Epoch: 98/100..  Train Loss: 0.089..  Train Median Error Rate: 0.051..  Validation Loss: 0.084..  Validation Median Error Rate: 0.048..
# Epoch: 99/100..  Train Loss: 0.089..  Train Median Error Rate: 0.050..  Validation Loss: 0.084..  Validation Median Error Rate: 0.045..
# Epoch: 100/100..  Train Loss: 0.088..  Train Median Error Rate: 0.049..  Validation Loss: 0.085..  Validation Median Error Rate: 0.049..

# %% [markdown]
# ## 2. A plot of the training errors and validation errors over epochs for a multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64.

# %%
#TODO: plot the training and validation error (MER) over epochs
plot_errors(train_errors, valid_errors, num_epochs=100, label1='Training Error', label2='Validation Error', title='Linear Regression: Training & Validation Errors (MER) Over Epochs')

# %% [markdown]
# ---
# ## Add norm regularization
#
# In the following, use the norm regularization to retrain the above MLP.

# %%
#TODO: plot the training and validation error (MER) over epochs after using norm regularization
def train(model, train_loader, valid_loader,weight_decay,num_epochs,learning_rate):
    train_losses = []                                       # To store training losses
    train_errors = []
    valid_losses=[]
    valid_errors=[]
    # To store training error rates
    # Initialize the optimizer, we use Adam here
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
    for epoch in range(num_epochs):
        tot_valid_loss = 0.0
        tot_train_loss = 0.0                            # Store the total training MSE loss for this epoch
        train_error_rates =torch.tensor([]).to(device)  # Store the training error rates for this epoch
        valid_error_rates=torch.tensor([]).to(device)
        for features, labels in train_loader:           # For each batch in DataLoader
            # Move data to device (GPU or CPU)
            features = features.to(device)
            labels = labels.to(device)

            output = model(features)  # Compute the output
            loss = criterion(output, labels)  # Compute loss
            loss = loss.mean()
            optimizer.zero_grad()  # Clear the gradients from previous iteration
            loss.backward()  # Backpropagate the error
            optimizer.step()  # Update the weights

            tot_train_loss += loss.item()

            # Compute and store error rate for training data
            train_error_rate = torch.absolute(output/labels-1)
            train_error_rates= torch.cat((train_error_rates,train_error_rate),dim=0)


        train_loss = tot_train_loss /len(train_loader)
        train_error = torch.median(train_error_rates).item()
        train_losses.append(train_loss)
        train_errors.append(train_error)


        for valid_features, valid_labels in valid_loader:

            valid_features = valid_features.to(device)
            valid_labels = valid_labels.to(device)
            output = model(valid_features)
            loss = criterion(output, valid_labels)
            loss = loss.mean()
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            tot_valid_loss += loss.item()

            valid_error_rate = torch.absolute(output/valid_labels-1)
            valid_error_rates= torch.cat((valid_error_rates,valid_error_rate),dim=0)

        valid_loss = tot_valid_loss /len(valid_loader)
        valid_error = torch.median(valid_error_rates).item()
        valid_losses.append(valid_loss)
        valid_errors.append(valid_error)

        print("Epoch: {}/{}.. ".format(epoch+1, num_epochs),
          "Train Loss: {:.3f}.. ".format(train_loss),
          "Train Median Error Rate: {:.3f}.. ".format(train_error),
          "Validation Loss: {:.3f}.. ".format(valid_loss),
          "Validation Median Error Rate: {:.3f}.. ".format(valid_error))


        # Print the training loss and validation loss every 10 epochs
        if epoch % 10 == 0:
            print("Epoch: {}/{}.. ".format(epoch+1, num_epochs),
              "Train Loss: {:.3f}.. ".format(train_loss),
              "Train Median Error Rate: {:.3f}.. ".format(train_error),
              )


    return  train_losses,train_errors,valid_losses,valid_errors

# %%
train_losses,train_errors,valid_losses,valid_errors = train(model2, train_loader,valid_loader,weight_decay=0.00001, num_epochs=100,learning_rate=0.0005)
# Out:
# Epoch: 1/100..  Train Loss: 0.082..  Train Median Error Rate: 0.042..  Validation Loss: 0.083..  Validation Median Error Rate: 0.048..
# Epoch: 1/100..  Train Loss: 0.082..  Train Median Error Rate: 0.042..
# Epoch: 2/100..  Train Loss: 0.083..  Train Median Error Rate: 0.043..  Validation Loss: 0.084..  Validation Median Error Rate: 0.049..
# Epoch: 3/100..  Train Loss: 0.080..  Train Median Error Rate: 0.041..  Validation Loss: 0.077..  Validation Median Error Rate: 0.040..
# Epoch: 4/100..  Train Loss: 0.077..  Train Median Error Rate: 0.038..  Validation Loss: 0.076..  Validation Median Error Rate: 0.039..
# Epoch: 5/100..  Train Loss: 0.077..  Train Median Error Rate: 0.037..  Validation Loss: 0.079..  Validation Median Error Rate: 0.041..
# Epoch: 6/100..  Train Loss: 0.079..  Train Median Error Rate: 0.039..  Validation Loss: 0.076..  Validation Median Error Rate: 0.039..
# Epoch: 7/100..  Train Loss: 0.078..  Train Median Error Rate: 0.039..  Validation Loss: 0.075..  Validation Median Error Rate: 0.038..
# Epoch: 8/100..  Train Loss: 0.077..  Train Median Error Rate: 0.038..  Validation Loss: 0.075..  Validation Median Error Rate: 0.037..
# Epoch: 9/100..  Train Loss: 0.076..  Train Median Error Rate: 0.037..  Validation Loss: 0.074..  Validation Median Error Rate: 0.035..
# Epoch: 10/100..  Train Loss: 0.075..  Train Median Error Rate: 0.036..  Validation Loss: 0.075..  Validation Median Error Rate: 0.037..
# Epoch: 11/100..  Train Loss: 0.076..  Train Median Error Rate: 0.037..  Validation Loss: 0.078..  Validation Median Error Rate: 0.040..
# Epoch: 11/100..  Train Loss: 0.076..  Train Median Error Rate: 0.037..
# Epoch: 12/100..  Train Loss: 0.077..  Train Median Error Rate: 0.038..  Validation Loss: 0.073..  Validation Median Error Rate: 0.038..
# Epoch: 13/100..  Train Loss: 0.075..  Train Median Error Rate: 0.036..  Validation Loss: 0.072..  Validation Median Error Rate: 0.033..
# Epoch: 14/100..  Train Loss: 0.076..  Train Median Error Rate: 0.038..  Validation Loss: 0.071..  Validation Median Error Rate: 0.033..
100..  Train Loss: 0.064..  Train Median Error Rate: 0.030..  Validation Loss: 0.061..  Validation Median Error Rate: 0.028..
# Epoch: 91/100..  Train Loss: 0.065..  Train Median Error Rate: 0.032..  Validation Loss: 0.062..  Validation Median Error Rate: 0.028..
# Epoch: 91/100..  Train Loss: 0.065..  Train Median Error Rate: 0.032..
# Epoch: 92/100..  Train Loss: 0.066..  Train Median Error Rate: 0.032..  Validation Loss: 0.063..  Validation Median Error Rate: 0.029..
# Epoch: 93/100..  Train Loss: 0.065..  Train Median Error Rate: 0.030..  Validation Loss: 0.061..  Validation Median Error Rate: 0.027..
# Epoch: 94/100..  Train Loss: 0.064..  Train Median Error Rate: 0.029..  Validation Loss: 0.061..  Validation Median Error Rate: 0.026..
# Epoch: 95/100..  Train Loss: 0.064..  Train Median Error Rate: 0.030..  Validation Loss: 0.062..  Validation Median Error Rate: 0.029..
# Epoch: 96/100..  Train Loss: 0.064..  Train Median Error Rate: 0.031..  Validation Loss: 0.063..  Validation Median Error Rate: 0.028..
# Epoch: 97/100..  Train Loss: 0.064..  Train Median Error Rate: 0.030..  Validation Loss: 0.062..  Validation Median Error Rate: 0.028..
# Epoch: 98/100..  Train Loss: 0.064..  Train Median Error Rate: 0.030..  Validation Loss: 0.062..  Validation Median Error Rate: 0.030..
# Epoch: 99/100..  Train Loss: 0.064..  Train Median Error Rate: 0.030..  Validation Loss: 0.060..  Validation Median Error Rate: 0.027..
# Epoch: 100/100..  Train Loss: 0.064..  Train Median Error Rate: 0.030..  Validation Loss: 0.061..  Validation Median Error Rate: 0.027..

# %% [markdown]
# ## 3. A plot of the training errors and validation errors over epochs for a multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64 and norm regularization.

# %%
plot_errors(train_errors, valid_errors, num_epochs=100, label1='Training Error', label2='Validation Error', title='Linear Regression: Training & Validation Errors (MER) Over Epochs')

# %% [markdown]
# ---
# ## Add dropout layer
#
# In the following, add dropout layer to the above MLP.

# %%
#TODO: plot the training and validation error (MER) over epochs after using norm regularization
model3 = nn.Sequential(nn.Linear(train_features.shape[1], 512),
    nn.ReLU(),
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Linear(256, 128),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Linear(128, 64),
    nn.ReLU(),
    nn.Linear(64, 1))
model3 = model3.to(device)
train_losses,train_errors,valid_losses,valid_errors = train(model3, train_loader,valid_loader,weight_decay=0.00001, num_epochs=200,learning_rate=0.001)
# Out:
# Epoch: 1/200..  Train Loss: 0.397..  Train Median Error Rate: 0.285..  Validation Loss: 0.223..  Validation Median Error Rate: 0.165..
# Epoch: 1/200..  Train Loss: 0.397..  Train Median Error Rate: 0.285..
# Epoch: 2/200..  Train Loss: 0.216..  Train Median Error Rate: 0.153..  Validation Loss: 0.186..  Validation Median Error Rate: 0.137..
# Epoch: 3/200..  Train Loss: 0.194..  Train Median Error Rate: 0.131..  Validation Loss: 0.181..  Validation Median Error Rate: 0.135..
# Epoch: 4/200..  Train Loss: 0.187..  Train Median Error Rate: 0.126..  Validation Loss: 0.178..  Validation Median Error Rate: 0.130..
# Epoch: 5/200..  Train Loss: 0.184..  Train Median Error Rate: 0.127..  Validation Loss: 0.174..  Validation Median Error Rate: 0.130..
# Epoch: 6/200..  Train Loss: 0.179..  Train Median Error Rate: 0.122..  Validation Loss: 0.169..  Validation Median Error Rate: 0.126..
# Epoch: 7/200..  Train Loss: 0.174..  Train Median Error Rate: 0.119..  Validation Loss: 0.164..  Validation Median Error Rate: 0.123..
# Epoch: 8/200..  Train Loss: 0.179..  Train Median Error Rate: 0.123..  Validation Loss: 0.161..  Validation Median Error Rate: 0.112..
# Epoch: 9/200..  Train Loss: 0.168..  Train Median Error Rate: 0.114..  Validation Loss: 0.163..  Validation Median Error Rate: 0.120..
# Epoch: 10/200..  Train Loss: 0.162..  Train Median Error Rate: 0.109..  Validation Loss: 0.156..  Validation Median Error Rate: 0.110..
# Epoch: 11/200..  Train Loss: 0.165..  Train Median Error Rate: 0.112..  Validation Loss: 0.156..  Validation Median Error Rate: 0.111..
200..  Train Loss: 0.081..  Train Median Error Rate: 0.046..  Validation Loss: 0.078..  Validation Median Error Rate: 0.045..
# Epoch: 174/200..  Train Loss: 0.081..  Train Median Error Rate: 0.048..  Validation Loss: 0.077..  Validation Median Error Rate: 0.044..
# Epoch: 175/200..  Train Loss: 0.081..  Train Median Error Rate: 0.046..  Validation Loss: 0.080..  Validation Median Error Rate: 0.047..
# Epoch: 176/200..  Train Loss: 0.081..  Train Median Error Rate: 0.046..  Validation Loss: 0.077..  Validation Median Error Rate: 0.045..
# Epoch: 177/200..  Train Loss: 0.081..  Train Median Error Rate: 0.046..  Validation Loss: 0.082..  Validation Median Error Rate: 0.048..
# Epoch: 178/200..  Train Loss: 0.080..  Train Median Error Rate: 0.045..  Validation Loss: 0.080..  Validation Median Error Rate: 0.047..
# Epoch: 179/200..  Train Loss: 0.083..  Train Median Error Rate: 0.047..  Validation Loss: 0.085..  Validation Median Error Rate: 0.051..
# Epoch: 180/200..  Train Loss: 0.081..  Train Median Error Rate: 0.046..  Validation Loss: 0.077..  Validation Median Error Rate: 0.044..
# Epoch: 181/200..  Train Loss: 0.079..  Train Median Error Rate: 0.045..  Validation Loss: 0.077..  Validation Median Error Rate: 0.044..
# Epoch: 181/200..  Train Loss: 0.079..  Train Median Error Rate: 0.045..
# Epoch: 182/200..  Train Loss: 0.083..  Train Median Error Rate: 0.048..  Validation Loss: 0.080..  Validation Median Error Rate: 0.048..
# Epoch: 183/200..  Train Loss: 0.084..  Train Median Error Rate: 0.049..  Validation Loss: 0.078..  Validation Median Error Rate: 0.044..
# Epoch: 184/200..  Train Loss: 0.081..  Train Median Error Rate: 0.047..  Validation Loss: 0.078..  Validation Median Error Rate: 0.044..
# Epoch: 185/200..  Train Loss: 0.079..  Train Median Error Rate: 0.045..  Validation Loss: 0.077..  Validation Median Error Rate: 0.044..
# Epoch: 186/200..  Train Loss: 0.079..  Train Median Error Rate: 0.045..  Validation Loss: 0.077..  Validation Median Error Rate: 0.043..
# Epoch: 187/200..  Train Loss: 0.079..  Train Median Error Rate: 0.045..  Validation Loss: 0.077..  Validation Median Error Rate: 0.045..
# Epoch: 188/200..  Train Loss: 0.079..  Train Median Error Rate: 0.044..  Validation Loss: 0.076..  Validation Median Error Rate: 0.043..
# Epoch: 189/200..  Train Loss: 0.079..  Train Median Error Rate: 0.045..  Validation Loss: 0.077..  Validation Median Error Rate: 0.045..
# Epoch: 190/200..  Train Loss: 0.082..  Train Median Error Rate: 0.047..  Validation Loss: 0.080..  Validation Median Error Rate: 0.046..
# Epoch: 191/200..  Train Loss: 0.082..  Train Median Error Rate: 0.048..  Validation Loss: 0.079..  Validation Median Error Rate: 0.048..
# Epoch: 191/200..  Train Loss: 0.082..  Train Median Error Rate: 0.048..
# Epoch: 192/200..  Train Loss: 0.080..  Train Median Error Rate: 0.046..  Validation Loss: 0.080..  Validation Median Error Rate: 0.047..
# Epoch: 193/200..  Train Loss: 0.081..  Train Median Error Rate: 0.047..  Validation Loss: 0.077..  Validation Median Error Rate: 0.044..
# Epoch: 194/200..  Train Loss: 0.079..  Train Median Error Rate: 0.046..  Validation Loss: 0.080..  Validation Median Error Rate: 0.047..
# Epoch: 195/200..  Train Loss: 0.080..  Train Median Error Rate: 0.045..  Validation Loss: 0.078..  Validation Median Error Rate: 0.043..
# Epoch: 196/200..  Train Loss: 0.079..  Train Median Error Rate: 0.045..  Validation Loss: 0.077..  Validation Median Error Rate: 0.044..
# Epoch: 197/200..  Train Loss: 0.079..  Train Median Error Rate: 0.045..  Validation Loss: 0.077..  Validation Median Error Rate: 0.046..
# Epoch: 198/200..  Train Loss: 0.080..  Train Median Error Rate: 0.046..  Validation Loss: 0.078..  Validation Median Error Rate: 0.047..
# Epoch: 199/200..  Train Loss: 0.078..  Train Median Error Rate: 0.044..  Validation Loss: 0.076..  Validation Median Error Rate: 0.044..
# Epoch: 200/200..  Train Loss: 0.079..  Train Median Error Rate: 0.044..  Validation Loss: 0.084..  Validation Median Error Rate: 0.049..

# %% [markdown]
# ## 4.  A plot of the training errors and validation errors over epochs for a multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64 and norm regularization and dropout layers.

# %%
plot_errors(train_errors, valid_errors, num_epochs=200, label1='Training Error', label2='Validation Error', title='Linear Regression: Training & Validation Errors (MER) Over Epochs')

# %% [markdown]
# ## Some other model variations
#
# **You're more than welcome to try some other model varations (e.g. different number of hidden layers, hidden neurons, learning rate, etc) to achieve lower valid error. Include a table listing all the model hyperparameters that you have tried with the corresponding validation errors that you found.**

# %%
#Number of layers
#Number of neurons
#Learning rate
#Regularization
#dropout layer
model4=nn.Sequential(nn.Linear(train_features.shape[1], 71),
                      nn.ReLU(),
                      nn.Linear(71,1024),
                      nn.ReLU(),
                      nn.Linear(1024,512),
                      nn.ReLU(),
                     nn.Linear(512,256),
                      nn.ReLU(),
                     nn.Linear(256,128),
                      nn.ReLU(),
                     #nn.Linear(128,64),
700..  Train Loss: 0.043..  Train Median Error Rate: 0.020..  Validation Loss: 0.042..  Validation Median Error Rate: 0.020..
# Epoch: 697/700..  Train Loss: 0.044..  Train Median Error Rate: 0.020..  Validation Loss: 0.044..  Validation Median Error Rate: 0.021..
# Epoch: 698/700..  Train Loss: 0.044..  Train Median Error Rate: 0.021..  Validation Loss: 0.045..  Validation Median Error Rate: 0.022..
# Epoch: 699/700..  Train Loss: 0.046..  Train Median Error Rate: 0.022..  Validation Loss: 0.044..  Validation Median Error Rate: 0.021..
# Epoch: 700/700..  Train Loss: 0.044..  Train Median Error Rate: 0.021..  Validation Loss: 0.042..  Validation Median Error Rate: 0.020..

# %%
plot_errors(train_errors, valid_errors, num_epochs=700, label1='Training Error', label2='Validation Error', title='Linear Regression: Training & Validation Errors (MER) Over Epochs')

# %%
model5=nn.Sequential(nn.Linear(train_features.shape[1], 71),
                      nn.ReLU(),
                      nn.Linear(71,2048),
                      nn.ReLU(),
                      nn.Linear(2048,1024),
                      nn.ReLU(),
                      nn.Linear(1024,512),
                      nn.ReLU(),
                      nn.Linear(512,64),
                      nn.ReLU(),
                      nn.Linear(64,1))

model5 = model5.to(device)
train_losses,train_errors,valid_losses,valid_errors = train(model5, train_loader,valid_loader,weight_decay=0.00001, num_epochs=700,learning_rate=0.0005)
# Out:
# Epoch: 1/700..  Train Loss: 0.358..  Train Median Error Rate: 0.252..  Validation Loss: 0.220..  Validation Median Error Rate: 0.162..
# Epoch: 1/700..  Train Loss: 0.358..  Train Median Error Rate: 0.252..
# Epoch: 2/700..  Train Loss: 0.198..  Train Median Error Rate: 0.131..  Validation Loss: 0.183..  Validation Median Error Rate: 0.130..
# Epoch: 3/700..  Train Loss: 0.177..  Train Median Error Rate: 0.116..  Validation Loss: 0.159..  Validation Median Error Rate: 0.108..
# Epoch: 4/700..  Train Loss: 0.167..  Train Median Error Rate: 0.106..  Validation Loss: 0.154..  Validation Median Error Rate: 0.105..
# Epoch: 5/700..  Train Loss: 0.161..  Train Median Error Rate: 0.100..  Validation Loss: 0.153..  Validation Median Error Rate: 0.104..
# Epoch: 6/700..  Train Loss: 0.156..  Train Median Error Rate: 0.097..  Validation Loss: 0.156..  Validation Median Error Rate: 0.110..
# Epoch: 7/700..  Train Loss: 0.153..  Train Median Error Rate: 0.093..  Validation Loss: 0.148..  Validation Median Error Rate: 0.100..
# Epoch: 8/700..  Train Loss: 0.148..  Train Median Error Rate: 0.090..  Validation Loss: 0.141..  Validation Median Error Rate: 0.091..
# Epoch: 9/700..  Train Loss: 0.147..  Train Median Error Rate: 0.089..  Validation Loss: 0.136..  Validation Median Error Rate: 0.091..
# Epoch: 10/700..  Train Loss: 0.146..  Train Median Error Rate: 0.086..  Validation Loss: 0.136..  Validation Median Error Rate: 0.088..
# Epoch: 11/700..  Train Loss: 0.143..  Train Median Error Rate: 0.085..  Validation Loss: 0.130..  Validation Median Error Rate: 0.084..
# Epoch: 11/700..  Train Loss: 0.143..  Train Median Error Rate: 0.085..
# Epoch: 12/700..  Train Loss: 0.143..  Train Median Error Rate: 0.087..  Validation Loss: 0.134..  Validation Median Error Rate: 0.086..
# Epoch: 13/700..  Train Loss: 0.140..  Train Median Error Rate: 0.083..  Validation Loss: 0.129..  Validation Median Error Rate: 0.080..
# Epoch: 14/700..  Train Loss: 0.138..  Train Median Error Rate: 0.083..  Validation Loss: 0.127..  Validation Median Error Rate: 0.080..
# Epoch: 15/700..  Train Loss: 0.139..  Train Median Error Rate: 0.086..  Validation Loss: 0.126..  Validation Median Error Rate: 0.080..
# Epoch: 16/700..  Train Loss: 0.132..  Train Median Error Rate: 0.078..  Validation Loss: 0.130..  Validation Median Error Rate: 0.082..
700..  Train Loss: 0.043..  Train Median Error Rate: 0.021..  Validation Loss: 0.041..  Validation Median Error Rate: 0.020..
# Epoch: 688/700..  Train Loss: 0.044..  Train Median Error Rate: 0.022..  Validation Loss: 0.042..  Validation Median Error Rate: 0.020..
# Epoch: 689/700..  Train Loss: 0.043..  Train Median Error Rate: 0.020..  Validation Loss: 0.043..  Validation Median Error Rate: 0.022..
# Epoch: 690/700..  Train Loss: 0.043..  Train Median Error Rate: 0.021..  Validation Loss: 0.045..  Validation Median Error Rate: 0.024..
# Epoch: 691/700..  Train Loss: 0.044..  Train Median Error Rate: 0.021..  Validation Loss: 0.042..  Validation Median Error Rate: 0.022..
# Epoch: 691/700..  Train Loss: 0.044..  Train Median Error Rate: 0.021..
# Epoch: 692/700..  Train Loss: 0.043..  Train Median Error Rate: 0.020..  Validation Loss: 0.044..  Validation Median Error Rate: 0.023..
# Epoch: 693/700..  Train Loss: 0.045..  Train Median Error Rate: 0.022..  Validation Loss: 0.044..  Validation Median Error Rate: 0.024..
# Epoch: 694/700..  Train Loss: 0.045..  Train Median Error Rate: 0.023..  Validation Loss: 0.041..  Validation Median Error Rate: 0.021..
# Epoch: 695/700..  Train Loss: 0.043..  Train Median Error Rate: 0.021..  Validation Loss: 0.041..  Validation Median Error Rate: 0.021..
# Epoch: 696/700..  Train Loss: 0.043..  Train Median Error Rate: 0.021..  Validation Loss: 0.041..  Validation Median Error Rate: 0.020..
# Epoch: 697/700..  Train Loss: 0.042..  Train Median Error Rate: 0.020..  Validation Loss: 0.041..  Validation Median Error Rate: 0.019..
# Epoch: 698/700..  Train Loss: 0.042..  Train Median Error Rate: 0.020..  Validation Loss: 0.040..  Validation Median Error Rate: 0.018..
# Epoch: 699/700..  Train Loss: 0.043..  Train Median Error Rate: 0.021..  Validation Loss: 0.042..  Validation Median Error Rate: 0.021..
# Epoch: 700/700..  Train Loss: 0.043..  Train Median Error Rate: 0.021..  Validation Loss: 0.044..  Validation Median Error Rate: 0.024..

# %%
plot_errors(train_errors, valid_errors, num_epochs=700, label1='Training Error', label2='Validation Error', title='Linear Regression: Training & Validation Errors (MER) Over Epochs')

# %% [markdown]
# ## 5.A table listing all the model hyperparameters that you have tried with the corresponding validation errors that you found.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ## Save Model
#
# Save a `checkpoint.pth` file containing all the necessary information to retrieve your best model and predictions. Remember submitting this file to Canvas siste.
#
# Hint: Check out the `Lecture 4 - Saving and Loading Models.ipynb` on Canvas if you do not know how to save model.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms

import helper
import fc_model

# %%
print("Our model: \n\n", model5, '\n')
print("The state dict keys: \n\n", model5.state_dict().keys())
# Out:
# Our model:
#
#  Sequential(
#   (0): Linear(in_features=105, out_features=71, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=71, out_features=2048, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=2048, out_features=1024, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=1024, out_features=512, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=512, out_features=64, bias=True)
#   (9): ReLU()
#   (10): Linear(in_features=64, out_features=1, bias=True)
# )
#
# The state dict keys:
#
#  odict_keys(['0.weight', '0.bias', '2.weight', '2.bias', '4.weight', '4.bias', '6.weight', '6.bias', '8.weight', '8.bias', '10.weight', '10.bias'])

# %%
torch.save(model5.state_dict(), 'checkpoint.pth')

# %%
state_dict = torch.load('checkpoint.pth')
print(state_dict.keys())
# Out:
# odict_keys(['0.weight', '0.bias', '2.weight', '2.bias', '4.weight', '4.bias', '6.weight', '6.bias', '8.weight', '8.bias', '10.weight', '10.bias'])

# %%
model5.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %% [markdown]
# ---
# ## Inference on test data
#
# After the model is trained, we can use it for inference.

# %%
#TODO: write the code to generate predicted sale prices for test data
model5.eval()

test_features = test_features.to(device)

with torch.no_grad():
    predicted_test = model5(test_features) * normalization_factor

predicted_test_cpu = predicted_test.cpu()

# %%
#TODO: save the predicted sale prices into submission_csv
test_withid = pd.read_csv("test.csv")
ids = test_withid['ID'].values

submission = pd.DataFrame({'ID': ids, 'SALE_PRICE': predicted_test_cpu.view(-1)})
submission.to_csv('submission_best_model.csv',index=False)

# %% [markdown]
# Now, we can submit our predictions on Kaggle and see how they compare with the actual house prices (labels) on the test set.
#
# - Log in to the Kaggle website and visit the house price prediction competition page.
#
# - Click the “Submit Predictions”.
#
# - Click the “Browse Files” button in the dashed box at the bottom of the page and select the prediction file you wish to upload.
#
# - Click the “Submit” button at the bottom of the page to view your results.

# %% [markdown]
#  **Include your best test error shown on Kaggle in your case report!**

# %% [markdown]
# ---
# ## Evaluate the profit of iBuyer business model
#
#
# In class, we have dicussed the iBuyer business model and its opportunities and risks. In the following analysis, imagine you work in a consulting firm and would like to investigate the profitability of the iBuyer business model.
#
# You have taken the Mordern Analytics course and remembered that Prof. X advocated the data-driven approach in business decision making. Thus, you would like to perform analysis based on model and data.
#
# Note that since we do not know the true sale prices in the future (like test data), we need to conduct the analysis based on the historical data (train or validation data). Previously, you have already trained a multilayer perceptron model using the train data. Now, let's evaluate the profit of iBuyer business model based on the predicted prices on the **validation data**.

# %% [markdown]
# Let's first compute the predicted prices on the valid data.

# %% [markdown]
# ## 6. Your profit analysis of the iBuyer business model based on the predicted price on the valid data and answers to the four questions therein.

# %%
## TODO: Load your best model from your saved checkpoint.pth file.
state_dict = torch.load('checkpoint.pth')
model5.load_state_dict(state_dict)

# %%
## TODO: compute the predicted prices on valid data using your best model
model5.eval()
valid_features = valid_features.to(device)
with torch.no_grad():
    predicted_test = model5(valid_features) * normalization_factor

predicted_test_cpu = predicted_test.cpu()
predicted_test_cpu
# Out:
# tensor([[546081.8750],
#         [562118.2500],
#         [270428.5000],
#         ...,
#         [622495.1875],
#         [575214.8125],
#         [277230.6562]])

# %% [markdown]
# Compute the signed error rates (without taking the absolute value sign), that is
#
# $$
# \text{Signed Error Rate} = \frac{\text{Predicted Price}-\text{Actual Price}}{\text{Actual Price}}
# $$
# We will call signed error rate as prediction error henceafter.

# %%
valid_labels = valid_labels.to(device)
valid_labels
# Out:
# tensor([[5.6682],
#         [5.9000],
#         [2.5500],
#         ...,
#         [6.3000],
#         [5.9300],
#         [2.8090]], device='cuda:0')

# %%
## TODO: compute the signed error rates (henceafter called prediction errors)
predicted_test_cpu = predicted_test_cpu.to(device)
signed_error_rates = (predicted_test_cpu/(valid_labels*normalization_factor) - 1)
signed_error_rates
# Out:
# tensor([[-0.0366],
#         [-0.0473],
#         [ 0.0605],
#         ...,
#         [-0.0119],
#         [-0.0300],
#         [-0.0131]], device='cuda:0')

# %% [markdown]
# ### Analysis and visualization of valid errors

# %% [markdown]
# Let's plot the histogram of prediction errors.
#
# **Question 1**: what is the bias of the prediction errors? Include the histogram of prediction errors and the bias in your report.

# %%
error_rates = signed_error_rates.cpu().numpy()

# Plot a histogram
plt.hist(error_rates, bins=50, edgecolor='black', color='blue')
plt.title('Histogram of Signed Error Rates')
plt.xlabel('Signed Error Rate')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Profit Analysis
#
# In the following profit analysis, we assume the iBuyer will make an offer to every property in the valid data based on their predicted price $PP$. We assume the iBuyer decides the offer price $OP$ according to
# $$
# OP = \frac{PP}{1+\alpha},
# $$
# where $\alpha$ is the (targted) profit margin of the iBuyer.
# Here we assume the profit margin has already taken into consideration the commission fee charged by the iBuyer
# and various costs associated such as transaction cost, administration cost, and holding cost. Note that the commission fee charged by Zillow is often around $7.5\%$ and Zillow may charge additional repair costs after home inspection. Thus we take $\alpha=12\%$ in this case study.
#
# We further assume that the iBuyer can resell the property at the same
# price as the broker in the future once the property is bought. In other words, the resell price is equal to the sale price in the valid data. This assumption may not be exactly true in practice and the iBuyer may sell the house at either a higher or lower price depending on the market trend. But our conclusion will not change too much.
#
# Based on the above two assumptions, we can now determine the percentage profit
# for a property bought by the iBuyer as
# $$
# \frac{SP- OP}{OP}.
# $$
# We use the percentage profit instead of the absolute profit because the iBuyer cannot hope to purchase all houses in the market. Therefore, the percentage profit is a better measure of the profitability of the iBuyer business model.
#  The aim of the iBuyer in this simplified setting is to purchase properties for less money than they are sold for, to generate a profit.

# %%
profit_margin = 0.12

# %% [markdown]
# **Question 2**: Consider the hypothetical scenario where the offers are all accepted regardless of their values,
# what is the average percentage profit? Do you see a big difference compared to the profit margin $\alpha$? Include your answers in the report.

# %%
OP = predicted_test_cpu / (1 + profit_margin)
perc_profit = (valid_labels*normalization_factor)/OP - 1
avg_percentage_profit = torch.mean(perc_profit)
avg_percentage_profit
# Out:
# tensor(0.1845, device='cuda:0')

# %% [markdown]
# **Offer Acceptance Rule**
#
#
# However, not every offer will be accepted by the home owner. Given an offer price, whether the homeowner accepts it
# depends on the homeowner's perceived valuation. For the current dataset, we lack enough data to determine the homeowner's perceived valuation of the property. However, the actual sale price in the valid data serves as a reasonable proxy of the homeowner's perceived valuation. Therefore, we assume that the home owner will accept the offer, if
# $$
# OP> (1-\beta) SP,
# $$
# where $\beta$ is a discounting factor. Here the discounting factor captures the commission fee charged
# by the conventional realtors which is around 6%, as well as the convenience factor that models
# how much the homeowner values the quick transaction services of the iBuyer over the conventional
# relator. We assume $\beta = 10\%$ in this case.

# %% [markdown]
# **Question 3**: Based on the sale price in the valid data and the acceptance rule, what is the mean percentage profit among all accepted offers? Do you see a big difference compared to the targeted profit margin $\alpha$?  Include your answers in your report.

# %%
perc_profit2 = ((valid_labels*normalization_factor)/OP - 1)[OP > (0.9 * valid_labels * normalization_factor)]
avg_percentage_profit2 = torch.mean(perc_profit2)
avg_percentage_profit2
# Out:
# tensor(0.0458, device='cuda:0')

# %% [markdown]
# Let's plot the histogram of the prediction errors for those properties whose home owners accepted the offer.
#
# **Question 4**: What is the bias of the prediction errors when restricting to those properties whose owners accepted the offer? Based on the histogram and bias, can you explain your answers to Question 3?

# %%
signed_error_rates2 = (OP*(1+profit_margin)/(valid_labels*normalization_factor) - 1)[OP > (0.9 * valid_labels * normalization_factor)]
error_rates2= signed_error_rates2.cpu().numpy()

# Plot a histogram
plt.hist(error_rates2, bins=50, edgecolor='Black', color='blue')
plt.title('Histogram of Signed Error Rates')
plt.xlabel('Signed Error Rate')
plt.ylabel('Frequency')
plt.show()
